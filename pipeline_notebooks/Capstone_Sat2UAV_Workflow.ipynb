# %% [markdown]
# #**Capstone General Workflow**

# %% [markdown]
# ## Installing Dependencies & Setting Up Environment

# %% [markdown]
# ## Importing Orthomosaic/Satellite Imagery

# %%
# set max/min resolution/size?

# %% [markdown]
# ## Choosing UAV Trajectory and Imagery Parameters

# %%
# start point within image
# final point within orthomosaic
# (can integrate multiple points and create a polyline trajectory too - for cases where UAV is sent to check on critical infrastructure)
# preferred altidude of UAV
# chosen path option: linear, grid-map, custom (for multi-point)
# overlap coefficient (impacts size of generated dataset and how smooth the continous frames are if exported as simulated drone video footage)
# drone FOV/individual tile size

# outputs - est. number of dataset tiles, visualisation of path on orthomosaic

# %% [markdown]
# ## Extracting Raw Tiles from Chosen UAV Trajectory

# %% [markdown]
# ## Obtaining Higher Resolution Image Tiles

# %% [markdown]
# Upsampling Algorithm

# %% [markdown]
# Super Resolution

# %% [markdown]
# Diffusion Model

# %% [markdown]
# ## Applying Style Transfer/Image to Image Translation

# %%
# Style-transfer

# Visualise examples of final dataset

# %% [markdown]
# ## Extracting Final Dataset

# %%
# Save simulated UAV image tiles folder to zip folder
# Potential to combine into simulated UAV drone video

# %% [markdown]
# ## Running Rubble Detection Model on Dataset

# %%
# import binary rubble detection model
# run inference on batch of images
# output visualisation of segmentation labels and extract label metadata

# %% [markdown]
# ## UAV Path Planning Using Detection Outputs
